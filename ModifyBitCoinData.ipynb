# %%
from pyspark.sql import SparkSession
import pyspark.sql.types as st
from pyspark.sql.types import StructType,StructField, StringType
from pyspark.sql import  functions
from pyspark.sql.functions import col, lower, to_date, to_timestamp, to_utc_timestamp, month, year, weekofyear, dayofmonth
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## EXTEND CURRENT DF

# %% [markdown]
# ####1) Load block level data for all coins from MNT location
# ####2) Get unique miners list for all the coins

# %%
#bitcoin
bitcoin_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_tsv_rdd_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#bitcoin cash
bitcoin_cash_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bc_block_sub_df_exported.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#bitcoin SV
bitcoin_sv_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/BC-SV/bcsv_block_tsv_rdd_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dash
dash_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_tsv_rdd_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dogecoin
dogecoin_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_tsv_rdd_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#ethereum
ehtereum_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/Ethereum/df_ethereum_block_tsv_rdd_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#lite coin
litecoin_block_df = spark.read.csv(path="dbfs:/mnt/BlockChain/Blocks/LiteCoin/block_df.csv", header=True,  inferSchema= True, sep=",")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
bitcoin_miner_grp = sorted(bitcoin_block_df.groupBy("guessed_miner").count().collect(), key = lambda row: row["count"], reverse= True)
display(bitcoin_miner_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>guessed_miner</th><th>count</th></tr></thead><tbody><tr><td>Unknown</td><td>246536</td></tr><tr><td>F2Pool</td><td>61487</td></tr><tr><td>AntPool</td><td>53239</td></tr><tr><td>SlushPool</td><td>34016</td></tr><tr><td>BTC Guild</td><td>32496</td></tr><tr><td>BTC.com</td><td>32447</td></tr><tr><td>GHash.IO</td><td>22791</td></tr><tr><td>ViaBTC</td><td>20571</td></tr><tr><td>BitFury</td><td>19279</td></tr><tr><td>BTCC Pool</td><td>17767</td></tr><tr><td>BTC.TOP</td><td>16607</td></tr><tr><td>BW.COM</td><td>12218</td></tr><tr><td>Eligius</td><td>11293</td></tr><tr><td>Poolin</td><td>8604</td></tr><tr><td>BitMinter</td><td>6369</td></tr><tr><td>50BTC</td><td>6262</td></tr><tr><td>KnCMiner</td><td>6227</td></tr><tr><td>BitClub Network</td><td>5598</td></tr><tr><td>OzCoin</td><td>4791</td></tr><tr><td>Huobi</td><td>4717</td></tr><tr><td>Binance</td><td>3941</td></tr><tr><td>EclipseMC</td><td>3433</td></tr><tr><td>Bixin</td><td>3306</td></tr><tr><td>1THash&58COIN</td><td>3137</td></tr><tr><td>ASICMiner</td><td>3057</td></tr><tr><td>Bitcoin.com</td><td>2440</td></tr><tr><td>KanoPool</td><td>2402</td></
</td><td>86</td></tr><tr><td>Bitcoin India</td><td>77</td></tr><tr><td>Mt Red</td><td>77</td></tr><tr><td>shawnp0wers</td><td>67</td></tr><tr><td>8baochi</td><td>51</td></tr><tr><td>ST Mining Corp</td><td>48</td></tr><tr><td>PHash.IO</td><td>44</td></tr><tr><td>simplecoin.us</td><td>43</td></tr><tr><td>mmpool</td><td>39</td></tr><tr><td>Waterhole</td><td>35</td></tr><tr><td>BTCDig</td><td>33</td></tr><tr><td>MiningKings</td><td>32</td></tr><tr><td>HAOZHUZHU</td><td>25</td></tr><tr><td>transactioncoinmining</td><td>24</td></tr><tr><td>Eobot</td><td>23</td></tr><tr><td>1Hash</td><td>22</td></tr><tr><td>175btc</td><td>22</td></tr><tr><td>Bitsolo</td><td>22</td></tr><tr><td>HashBX</td><td>18</td></tr><tr><td>NiceHash Solo</td><td>18</td></tr><tr><td>HotPool</td><td>17</td></tr><tr><td>A-XBT</td><td>16</td></tr><tr><td>BCMonster</td><td>15</td></tr><tr><td>Bravo Mining</td><td>13</td></tr><tr><td>BitcoinRussia</td><td>11</td></tr><tr><td>Mining Dutch</td><td>9</td></tr><tr><td>BTCServ</td><td>9</td></tr><tr><td>bcpool.io</td><td>8</td></tr><tr><td>myBTCcoin Pool</td><td>8</td></tr><tr><td>TBDice</td><td>4</td></tr><tr><td>bchpool</td><td>4</td></tr><tr><td>Multipool</td><td>3</td></tr><tr><td>Patel\'s Mining pool</td><td>2</td></tr><tr><td>7pool</td><td>1</td></tr><tr><td>BTCMP</td><td>1</td></tr><tr><td>EkanemBTC</td><td>1</td></tr><tr><td>Nexious</td><td>1</td></tr><tr><td>Tricky\'s BTC Pool</td><td>1</td></tr><tr><td>HASHPOOL</td><td>1</td></tr><tr><td>RigPool</td><td>1</td></tr></tbody></table></div>

# %%
bitcoin_SV_miners_grp = sorted(bitcoin_sv_block_df.groupBy("guessed_miner").count().collect(), key= lambda row: row["count"], reverse= True)
display(bitcoin_SV_miners_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>guessed_miner</th><th>count</th></tr></thead><tbody><tr><td>Unknown</td><td>290885</td></tr><tr><td>F2Pool</td><td>37074</td></tr><tr><td>AntPool</td><td>32628</td></tr><tr><td>BTC Guild</td><td>30919</td></tr><tr><td>ViaBTC</td><td>23573</td></tr><tr><td>GHash.IO</td><td>21986</td></tr><tr><td>CoinGeek</td><td>20329</td></tr><tr><td>SlushPool</td><td>18860</td></tr><tr><td>BTCC Pool</td><td>14976</td></tr><tr><td>BitFury</td><td>14589</td></tr><tr><td>BTC.TOP</td><td>13959</td></tr><tr><td>svpool.com</td><td>11143</td></tr><tr><td>taal.com</td><td>11031</td></tr><tr><td>Eligius</td><td>10980</td></tr><tr><td>BW.COM</td><td>10895</td></tr><tr><td>BTC.com</td><td>8511</td></tr><tr><td>BMG Pool</td><td>8047</td></tr><tr><td>Bitcoin.com</td><td>7312</td></tr><tr><td>Mempool.com</td><td>6789</td></tr><tr><td>KnCMiner</td><td>6000</td></tr><tr><td>BitMinter</td><td>5994</td></tr><tr><td>50BTC</td><td>5786</td></tr><tr><td>OzCoin</td><td>
# %%
dash_miners_grp = sorted(dash_block_df.groupBy("guessed_miner").count().collect(), key= lambda row: row["count"], reverse= True)
display(dash_miners_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>guessed_miner</th><th>count</th></tr></thead><tbody><tr><td>Unknown</td><td>382521</td></tr><tr><td>AntPool</td><td>72241</td></tr><tr><td>ViaBTC</td><td>24378</td></tr><tr><td>F2Pool</td><td>23287</td></tr><tr><td>CybtcPool</td><td>21931</td></tr><tr><td>Poolin.com</td><td>7229</td></tr><tr><td>GHash.IO</td><td>1751</td></tr><tr><td>NiceHash Solo</td><td>436</td></tr><tr><td>Multipool.us</td><td>61</td></tr><tr><td>EclipseMC</td><td>2</td></tr><tr><td>mmpool</td><td>1</td></tr></tbody></table></div>

# %%
dogecoin_miners_grp = sorted(dogecoin_block_df.groupBy("guessed_miner").count().collect(), key= lambda row: row["count"], reverse= True)
display(dogecoin_miners_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>guessed_miner</th><th>count</th></tr></thead><tbody><tr><td>Unknown</td><td>3620235</td></tr><tr><td>TBDice</td><td>19052</td></tr><tr><td>GHash.IO</td><td>10161</td></tr><tr><td>BTCC Pool</td><td>6918</td></tr><tr><td>BTC Guild</td><td>6382</td></tr></tbody></table></div>

# %%
ethereum_miners_grp = sorted(ehtereum_block_df.groupBy("miner").count().collect(), key= lambda row: row["count"], reverse= True)
display(ethereum_miners_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>miner</th><th>count</th></tr></thead><tbody><tr><td>0xea674fdde714fd979de3edf0f56aa9716b898ec8</td><td>185153</td></tr><tr><td>0x5a0b54d5dc17e0aadc383d2db43b0a0d3e029c4c</td><td>135845</td></tr><tr><td>0x52bc44d5378309ee2abf1539bf71de1b7d7be3b5</td><td>88201</td></tr><tr><td>0x829bd824b016326a401d083b33d092293333a830</td><td>87086</td></tr><tr><td>0x2a65aca4d5fc5b5c859090a6c34d164135398226</td><td>68667</td></tr><tr><td>0xb2930b35844a230f00e51431acae96fe543a0347</td><td>37824</td></tr><tr><td>0x61c808d82a3ac53231750dadc13c777b59310bd9</td><td>35629</td></tr><tr><td>0x4bb96091ee9d802ed039c4d1a5f6216f90f81b01</td><td>21900</td></tr><tr><td>0x04668ec2f57cc15c381b461b9fedab5d451c8f7f</td><td>17152</td></tr><tr><td>0x1e9939daaad6924ad004c2560e90804164900341</td><td>12929</td></tr><tr><td>0xc0ea08a2d404d3172d2add29a45be56da40e2949</td><td>12761</td></tr><tr><td>0xf8b483dba2c3b7176a3da549ad41a48bb3121069</td><td>10833</td></tr><tr><td>0xf3b9d2c81f2b24b0fa0acaaa865b7d9ced5fc2fb</td><td>7939</td></tr><tr><td>0xbcdfc35b86bedf72f0cda046a3c16829a2ef41d1</td><td>7512</td></tr><tr><td>0xd224ca0c819e8e97ba0136b3b95ceff503b79f53</td><td>7371</td></
# %%
litecoin_miners_grp = sorted(litecoin_block_df.groupBy("guessed_miner").count().collect(), key= lambda row: row["count"], reverse= True)
display(litecoin_miners_grp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>guessed_miner</th><th>count</th></tr></thead><tbody><tr><td>Unknown</td><td>291498</td></tr><tr><td>F2Pool</td><td>108581</td></tr><tr><td>AntPool</td><td>40258</td></tr><tr><td>litecoinpool.org</td><td>33022</td></tr><tr><td>ViaBTC</td><td>26325</td></tr><tr><td>LTC.TOP</td><td>25663</td></tr><tr><td>Poolin</td><td>14776</td></tr><tr><td>BTC.com</td><td>11794</td></tr><tr><td>Easy2Mine</td><td>8237</td></tr><tr><td>gly.pool</td><td>2701</td></tr><tr><td>TBDice</td><td>2401</td></tr><tr><td>HuoBi</td><td>2252</td></tr><tr><td>BATPOOL</td><td>1617</td></tr><tr><td>BTCC Pool</td><td>1359</td></tr><tr><td>DPOOL</td><td>853</td></tr><tr><td>GHash.IO</td><td>633</td></tr><tr><td>Sigmapool</td><td>417</td></tr><tr><td>NiceHash Solo</td><td>164</td></tr><tr><td>BTC Guild</td><td>81</td></tr><tr><td>OzCoin</td><td>31</td></tr></tbody></table></div>

# %% [markdown]
# ## ADD Year, Month, Week and isPool columns to existing DF

# %% [markdown]
# #### BITCION DF EXTESNION

# %%
bitcoin_block_extended_df = bitcoin_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(bitcoin_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-------------------+-------------------+----+-------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
#    ID|               time|        median_time|size|guessed_miner|     difficulty|fee_total|fee_total_usd|    reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +-----+-------------------+-------------------+----+-------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# 66208|2010-07-13 00:00:14|2010-07-12 23:47:29| 374|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66209|2010-07-13 00:00:56|2010-07-12 23:53:08| 374|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66210|2010-07-13 00:01:31|2010-07-12 23:53:31| 216|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66211|2010-07-13 00:01:49|2010-07-12 23:57:17| 474|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66212|2010-07-13 00:02:34|2010-07-12 23:57:33| 474|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66213|2010-07-13 00:04:10|2010-07-13 00:00:14| 473|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66214|2010-07-13 00:04:53|2010-07-13 00:00:56| 216|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66215|2010-07-13 00:02:33|2010-07-13 00:01:31| 216|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66216|2010-07-13 00:05:49|2010-07-13 00:01:49| 475|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# 66217|2010-07-13 00:07:02|2010-07-13 00:02:33| 216|      Unknown|23.501257222903|        0|          0.0|5000000000|       0.5|2010-07-13|2010|    7|          28| false|
# +-----+-------------------+-------------------+----+-------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
bitcoin_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/BitCoin/" + "bitcoin_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[108]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv/_committed_7566536737500224522&#39;, name=&#39;_committed_7566536737500224522&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv/_started_7566536737500224522&#39;, name=&#39;_started_7566536737500224522&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv/part-00000-tid-7566536737500224522-750e84b1-aea4-4118-aeb2-4131f958ab63-465-1-c000.csv&#39;, name=&#39;part-00000-tid-7566536737500224522-750e84b1-aea4-4118-aeb2-4131f958ab63-465-1-c000.csv&#39;, size=94209733)]</div>

# %% [markdown]
# #### BITCOIN CASH DF EXTENSION

# %%
bitcoin_cash_block_extended_df = bitcoin_cash_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(bitcoin_cash_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------------------+-----+-------------------+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
#     ID|               time| size|        median_time|guessed_miner|       difficulty|fee_total|fee_total_usd|    reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +------+-------------------+-----+-------------------+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# 498641|2017-10-28 00:00:09| 2715|2017-10-27 23:52:43|       ViaBTC|6.901903578063E10|   102397|       0.4356|1250102397|  5318.498|2017-10-28|2017|   10|          43| false|
# 498642|2017-10-28 00:00:33|18476|2017-10-27 23:53:44|       ViaBTC|6.901903578063E10|   189556|       0.8065|1250189556| 5318.8691|2017-10-28|2017|   10|          43| false|
# 498643|2017-10-28 00:03:27| 3350|2017-10-27 23:53:54|      BTC.TOP|6.901903578063E10|   261416|       1.1122|1250261416| 5319.1748|2017-10-28|2017|   10|          43| false|
# 498644|2017-10-28 00:04:26| 3923|2017-10-27 23:56:13|       ViaBTC|6.901903578063E10|   197320|       0.8395|1250197320| 5318.9019|2017-10-28|2017|   10|          43| false|
# 498645|2017-10-28 00:04:44| 1564|2017-10-27 23:58:37|      BTC.TOP|6.901903578063E10|    32320|       0.1375|1250032320| 5318.2002|2017-10-28|2017|   10|          43| false|
# 498646|2017-10-28 00:05:32| 1264|2017-10-28 00:00:09|       F2Pool|6.901903578063E10|    10000|       0.0425|1250010000|  5318.105|2017-10-28|2017|   10|          43|  true|
# 498647|2017-10-28 00:06:19| 4573|2017-10-28 00:00:33|      BTC.TOP|6.901903578063E10|   133134|       0.5664|1250133134| 5318.6289|2017-10-28|2017|   10|          43| false|
# 498648|2017-10-28 00:06:44|  458|2017-10-28 00:03:27|      Unknown|6.901903578063E10|     6780|       0.0288|1250006780| 5318.0913|2017-10-28|2017|   10|          43| false|
# 498649|2017-10-28 00:07:28|  186|2017-10-28 00:04:26|      Unknown|6.901903578063E10|        0|          0.0|1250000000| 5318.0625|2017-10-28|2017|   10|          43| false|
# 498650|2017-10-28 00:07:38|  186|2017-10-28 00:04:44|      Unknown|6.901903578063E10|        0|          0.0|1250000000| 5318.0625|2017-10-28|2017|   10|          43| false|
# +------+-------------------+-----+-------------------+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
bitcoin_cash_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[109]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv/_committed_4036737947385536935&#39;, name=&#39;_committed_4036737947385536935&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv/_started_4036737947385536935&#39;, name=&#39;_started_4036737947385536935&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv/part-00000-tid-4036737947385536935-38f8267a-2b29-405f-ab92-bbd833906f7a-468-1-c000.csv&#39;, name=&#39;part-00000-tid-4036737947385536935-38f8267a-2b29-405f-ab92-bbd833906f7a-468-1-c000.csv&#39;, size=90656196)]</div>

# %% [markdown]
# #### BITCOIN-SV DF EXTENSION

# %%
bitcoin_sv_block_extended_df = bitcoin_sv_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(bitcoin_sv_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+-------------------+-------------------+-----+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
#     ID|               time|        median_time| size|guessed_miner|       difficulty|fee_total|fee_total_usd|    reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +------+-------------------+-------------------+-----+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# 498641|2017-10-28 00:00:09|2017-10-27 23:52:43| 2715|       ViaBTC|6.901903578063E10|   102397|       0.4356|1250102397|  5318.498|2017-10-28|2017|   10|          43| false|
# 498642|2017-10-28 00:00:33|2017-10-27 23:53:44|18476|       ViaBTC|6.901903578063E10|   189556|       0.8065|1250189556| 5318.8691|2017-10-28|2017|   10|          43| false|
# 498643|2017-10-28 00:03:27|2017-10-27 23:53:54| 3350|      BTC.TOP|6.901903578063E10|   261416|       1.1122|1250261416| 5319.1748|2017-10-28|2017|   10|          43| false|
# 498644|2017-10-28 00:04:26|2017-10-27 23:56:13| 3923|       ViaBTC|6.901903578063E10|   197320|       0.8395|1250197320| 5318.9019|2017-10-28|2017|   10|          43| false|
# 498645|2017-10-28 00:04:44|2017-10-27 23:58:37| 1564|      BTC.TOP|6.901903578063E10|    32320|       0.1375|1250032320| 5318.2002|2017-10-28|2017|   10|          43| false|
# 498646|2017-10-28 00:05:32|2017-10-28 00:00:09| 1264|       F2Pool|6.901903578063E10|    10000|       0.0425|1250010000|  5318.105|2017-10-28|2017|   10|          43|  true|
# 498647|2017-10-28 00:06:19|2017-10-28 00:00:33| 4573|      BTC.TOP|6.901903578063E10|   133134|       0.5664|1250133134| 5318.6289|2017-10-28|2017|   10|          43| false|
# 498648|2017-10-28 00:06:44|2017-10-28 00:03:27|  458|      Unknown|6.901903578063E10|     6780|       0.0288|1250006780| 5318.0913|2017-10-28|2017|   10|          43| false|
# 498649|2017-10-28 00:07:28|2017-10-28 00:04:26|  186|      Unknown|6.901903578063E10|        0|          0.0|1250000000| 5318.0625|2017-10-28|2017|   10|          43| false|
# 498650|2017-10-28 00:07:38|2017-10-28 00:04:44|  186|      Unknown|6.901903578063E10|        0|          0.0|1250000000| 5318.0625|2017-10-28|2017|   10|          43| false|
# +------+-------------------+-------------------+-----+-------------+-----------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
bitcoin_sv_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv")
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[112]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv/_committed_8129555006630370457&#39;, name=&#39;_committed_8129555006630370457&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv/_started_8129555006630370457&#39;, name=&#39;_started_8129555006630370457&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv/part-00000-tid-8129555006630370457-9ab8fd32-dc44-49c4-a28d-7f596ee741f9-469-1-c000.csv&#39;, name=&#39;part-00000-tid-8129555006630370457-9ab8fd32-dc44-49c4-a28d-7f596ee741f9-469-1-c000.csv&#39;, size=86828885)]</div>

# %% [markdown]
# #### DASH DF EXTENSION

# %%
dash_block_extended_df = dash_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dash_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+-------------------+------+-------------+-----------------+---------+-------------+---------+----------+----------+----+-----+------------+------+
#      ID|               time|        median_time|  size|guessed_miner|       difficulty|fee_total|fee_total_usd|   reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +-------+-------------------+-------------------+------+-------------+-----------------+---------+-------------+---------+----------+----------+----+-----+------------+------+
# 1180477|2019-12-02 00:00:57|2019-12-01 23:45:35|100657|       F2Pool|1.4342827851494E8|   122320|        0.065|310785012|  165.0579|2019-12-02|2019|   12|          49|  true|
# 1180478|2019-12-02 00:01:00|2019-12-01 23:46:28|  2179|      Unknown|1.3587167827611E8|      374|       2.0E-4|310663066|  164.9931|2019-12-02|2019|   12|          49| false|
# 1180479|2019-12-02 00:04:38|2019-12-01 23:46:48| 39356|      Unknown|1.3959976657051E8|   264144|       0.1403|310926836|  165.1332|2019-12-02|2019|   12|          49| false|
# 1180480|2019-12-02 00:08:20|2019-12-01 23:47:22|  6070|      AntPool|1.3481720271548E8|    14541|       0.0077|310677233|  165.0007|2019-12-02|2019|   12|          49|  true|
# 1180481|2019-12-02 00:10:49|2019-12-01 23:55:45| 42428|      Unknown| 1.392211025498E8|    54678|        0.029|310717370|   165.022|2019-12-02|2019|   12|          49| false|
# 1180482|2019-12-02 00:11:11|2019-12-02 00:00:57|  8438|      Unknown|1.3876830021612E8|     4278|       0.0023|310666970|  164.9952|2019-12-02|2019|   12|          49| false|
# 1180483|2019-12-02 00:13:55|2019-12-02 00:01:00| 36029|      Unknown|1.6399671724392E8|    35224|       0.0187|310697916|  165.0117|2019-12-02|2019|   12|          49| false|
# 1180484|2019-12-02 00:14:25|2019-12-02 00:04:38| 10108|      Unknown| 1.621289907864E8|    26306|        0.014|310688998|  165.0069|2019-12-02|2019|   12|          49| false|
# 1180485|2019-12-02 00:17:08|2019-12-02 00:08:20| 61287|      AntPool|1.7637952665417E8|    82280|       0.0437|310744972|  165.0367|2019-12-02|2019|   12|          49|  true|
# 1180486|2019-12-02 00:18:44|2019-12-02 00:10:49| 42647|      AntPool|1.6956667842011E8|    67371|       0.0358|310730063|  165.0287|2019-12-02|2019|   12|          49|  true|
# +-------+-------------------+-------------------+------+-------------+-----------------+---------+-------------+---------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
dash_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv")
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[113]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv/_committed_8928975158332151540&#39;, name=&#39;_committed_8928975158332151540&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv/_started_8928975158332151540&#39;, name=&#39;_started_8928975158332151540&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv/part-00000-tid-8928975158332151540-fd47e5c1-c6df-469f-ae8a-44b2ee464986-470-1-c000.csv&#39;, name=&#39;part-00000-tid-8928975158332151540-fd47e5c1-c6df-469f-ae8a-44b2ee464986-470-1-c000.csv&#39;, size=71970914)]</div>

# %% [markdown]
# #### DOGE COIN DF EXTENSION

# %%
dogecoin_block_extended_df = dogecoin_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dogecoin_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------------+-------------------+----+-------------+-------------+---------+-------------+--------------+----------+------+----------+----+-----+------------+------+
#  ID|               time|        median_time|size|guessed_miner|   difficulty|fee_total|fee_total_usd|        reward|reward_usd|is_aux|      Date|Year|Month|Week_of_Year|isPool|
# +---+-------------------+-------------------+----+-------------+-------------+---------+-------------+--------------+----------+------+----------+----+-----+------------+------+
#   1|2013-12-08 03:55:27|2013-12-08 03:55:27| 190|      Unknown|2.44140625E-4|        0|          0.0| 6841600000000|    6.8416|     0|2013-12-08|2013|   12|          49| false|
#   2|2013-12-08 03:55:33|2013-12-08 03:55:27| 190|      Unknown|2.44140625E-4|        0|          0.0|72975200000000|   72.9752|     0|2013-12-08|2013|   12|          49| false|
#   3|2013-12-08 03:55:40|2013-12-08 03:55:33| 190|      Unknown|2.44140625E-4|        0|          0.0| 1118300000000|    1.1183|     0|2013-12-08|2013|   12|          49| false|
#   4|2013-12-08 03:55:43|2013-12-08 03:55:33| 190|      Unknown|2.44140625E-4|        0|          0.0|32437800000000|   32.4378|     0|2013-12-08|2013|   12|          49| false|
#   5|2013-12-08 03:55:49|2013-12-08 03:55:40| 190|      Unknown|2.44140625E-4|        0|          0.0|26271100000000|   26.2711|     0|2013-12-08|2013|   12|          49| false|
#   6|2013-12-08 03:55:52|2013-12-08 03:55:40| 190|      Unknown|2.44140625E-4|        0|          0.0|86341300000000|   86.3413|     0|2013-12-08|2013|   12|          49| false|
#   7|2013-12-08 03:55:57|2013-12-08 03:55:43| 190|      Unknown|2.44140625E-4|        0|          0.0|14133900000000|   14.1339|     0|2013-12-08|2013|   12|          49| false|
#   8|2013-12-08 03:56:07|2013-12-08 03:55:43| 190|      Unknown|2.44140625E-4|        0|          0.0|85703500000000|   85.7035|     0|2013-12-08|2013|   12|          49| false|
#   9|2013-12-08 03:56:09|2013-12-08 03:55:49| 190|      Unknown|2.44140625E-4|        0|          0.0|51575800000000|   51.5758|     0|2013-12-08|2013|   12|          49| false|
#  10|2013-12-08 03:56:10|2013-12-08 03:55:49| 190|      Unknown|2.44140625E-4|        0|          0.0|89010700000000|   89.0107|     0|2013-12-08|2013|   12|          49| false|
# +---+-------------------+-------------------+----+-------------+-------------+---------+-------------+--------------+----------+------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
dogecoin_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv")
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[114]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv/_committed_8653220087950735950&#39;, name=&#39;_committed_8653220087950735950&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv/_started_8653220087950735950&#39;, name=&#39;_started_8653220087950735950&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv/part-00000-tid-8653220087950735950-fb274714-f345-4e7b-8947-2ee0d87b046d-471-1-c000.csv&#39;, name=&#39;part-00000-tid-8653220087950735950-fb274714-f345-4e7b-8947-2ee0d87b046d-471-1-c000.csv&#39;, size=525429302)]</div>

# %% [markdown]
# ####ETHEREUM DF EXTENSION

# %%
ehtereum_block_extended_df =  ehtereum_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(ehtereum_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------------+----+--------------------+-----------+---------+-------------+-------------------+----------+----------+----+-----+------------+------+
#  ID|               time|size|               miner| difficulty|fee_total|fee_total_usd|             reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +---+-------------------+----+--------------------+-----------+---------+-------------+-------------------+----------+----------+----+-----+------------+------+
#   0|2015-07-30 00:00:00| 540|0x000000000000000...|17179869184|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   1|2015-07-30 15:26:28| 537|0x05a56e2d52c8171...|17171480576|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   2|2015-07-30 15:26:57| 544|0xdd2f1e6e498202e...|17163096064|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   3|2015-07-30 15:27:28|1079|0x5088d623ba0fcf0...|17154715646|        0|          0.0|5156250000000000000|    5.1562|2015-07-30|2015|    7|          31| false|
#   4|2015-07-30 15:27:57|1079|0xc8ebccc5f5689fa...|17146339321|        0|          0.0|5156250000000000000|    5.1562|2015-07-30|2015|    7|          31| false|
#   5|2015-07-30 15:28:03| 537|0x05a56e2d52c8171...|17154711556|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   6|2015-07-30 15:28:27| 537|0x0193d941b50d91b...|17146335232|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   7|2015-07-30 15:28:30|1078|0xdd2f1e6e498202e...|17154707466|        0|          0.0|5156250000000000000|    5.1562|2015-07-30|2015|    7|          31| false|
#   8|2015-07-30 15:28:32| 537|0x0193d941b50d91b...|17163083788|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
#   9|2015-07-30 15:28:35| 544|0xdd2f1e6e498202e...|17171464200|        0|          0.0|5000000000000000000|       5.0|2015-07-30|2015|    7|          31| false|
# +---+-------------------+----+--------------------+-----------+---------+-------------+-------------------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
ehtereum_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv")
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">IllegalArgumentException</span>                  Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1971239298414363&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> ehtereum_block_extended_df<span class="ansi-blue-fg">.</span>coalesce<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;com.databricks.spark.csv&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>option<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;header&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;true&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>ls<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;dbfs://mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1619027813928-0/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    308</span>             <span class="ansi-green-fg">def</span> f_with_exception_handling<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>args<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    309</span>                 <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 310</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">return</span> f<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>args<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    311</span>                 <span class="ansi-green-fg">except</span> Py4JJavaError <span class="ansi-green-fg">as</span> e<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    312</span>                     <span class="ansi-green-fg">class</span> ExecutionError<span class="ansi-blue-fg">(</span>Exception<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1619027813928-0/dbutils.py</span> in <span class="ansi-cyan-fg">ls</span><span class="ansi-blue-fg">(self, path)</span>
# <span class="ansi-green-intense-fg ansi-bold">    340</span>         <span class="ansi-green-fg">def</span> ls<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> path<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    341</span>             self<span class="ansi-blue-fg">.</span>check_types<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">(</span>path<span class="ansi-blue-fg">,</span> string_types<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 342</span><span class="ansi-red-fg">             return self.create_list_from_jschema(self.print_return(self.fsutils.ls(path)),
# </span><span class="ansi-green-intense-fg ansi-bold">    343</span>                                                  FileInfo.create_from_jschema)
# <span class="ansi-green-intense-fg ansi-bold">    344</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    114</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    115</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 116</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    117</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    118</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">IllegalArgumentException</span>: Hostname not allowed in dbfs uri. Please use &#39;dbfs:/&#39; instead of &#39;dbfs://&#39; in uri: dbfs://mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv</div>

# %%
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[118]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv/_committed_1383242031298030066&#39;, name=&#39;_committed_1383242031298030066&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv/_started_1383242031298030066&#39;, name=&#39;_started_1383242031298030066&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv/part-00000-tid-1383242031298030066-9bb698a3-0ccb-432c-838b-ea4d233b0a29-472-1-c000.csv&#39;, name=&#39;part-00000-tid-1383242031298030066-9bb698a3-0ccb-432c-838b-ea4d233b0a29-472-1-c000.csv&#39;, size=158089066)]</div>

# %% [markdown]
# #### LITECOIN DF EXTENSION

# %%
litecoin_block_extended_df = litecoin_block_df.withColumn("Date", to_date(col("time"), format= "yyyy-MM-dd HH:mm:ss"))\
                                       .withColumn("Year",  year(col("Date")))\
                                       .withColumn("Month",month(col("Date")))\
                                       .withColumn("Week_of_Year", weekofyear(col("Date")))\
                                       .withColumn("isPool", lower(col("guessed_miner")).contains("pool"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(litecoin_block_extended_df.show(10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+-------------------+------+----------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
#      ID|               time|        median_time|  size|   guessed_miner|     difficulty|fee_total|fee_total_usd|    reward|reward_usd|      Date|Year|Month|Week_of_Year|isPool|
# +-------+-------------------+-------------------+------+----------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# 1326707|2017-12-07 00:01:55|2017-12-06 23:45:56|103371|         Unknown|1736261.9905441| 26445766|      27.1016|2526445766| 2589.1018|2017-12-07|2017|   12|          49| false|
# 1326708|2017-12-07 00:02:37|2017-12-06 23:49:16| 68383|         Unknown|1736261.9905441| 23144792|      23.7188|2523144792| 2585.7188|2017-12-07|2017|   12|          49| false|
# 1326709|2017-12-07 00:03:52|2017-12-06 23:50:20|   837|litecoinpool.org|1736261.9905441|   100000|       0.1025|2500100000| 2562.1025|2017-12-07|2017|   12|          49|  true|
# 1326710|2017-12-07 00:04:05|2017-12-06 23:50:35| 31297|          F2Pool|1736261.9905441|  7507574|       7.6938|2507507574| 2569.6938|2017-12-07|2017|   12|          49|  true|
# 1326711|2017-12-07 00:04:23|2017-12-06 23:55:02|  9825|         Unknown|1736261.9905441|  4757644|       4.8756|2504757644| 2566.8757|2017-12-07|2017|   12|          49| false|
# 1326712|2017-12-07 00:10:36|2017-12-07 00:01:55|126687|          ViaBTC|1736261.9905441| 39036713|      40.0048|2539036713| 2602.0049|2017-12-07|2017|   12|          49| false|
# 1326713|2017-12-07 00:11:08|2017-12-07 00:02:37|  8508|         Unknown|1736261.9905441|  4919021|        5.041|2504919021|  2567.041|2017-12-07|2017|   12|          49| false|
# 1326714|2017-12-07 00:12:13|2017-12-07 00:03:52|  9176|         AntPool|1736261.9905441|  5975648|       6.1238|2505975648|  2568.124|2017-12-07|2017|   12|          49|  true|
# 1326715|2017-12-07 00:13:46|2017-12-07 00:04:05| 43167|          F2Pool|1736261.9905441| 14457736|      14.8163|2514457736| 2576.8164|2017-12-07|2017|   12|          49|  true|
# 1326716|2017-12-07 00:13:59|2017-12-07 00:04:23|  2971|litecoinpool.org|1736261.9905441|   833635|       0.8543|2500833635| 2562.8545|2017-12-07|2017|   12|          49|  true|
# +-------+-------------------+-------------------+------+----------------+---------------+---------+-------------+----------+----------+----------+----+-----+------------+------+
# only showing top 10 rows
#
# </div>

# %%
litecoin_block_extended_df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv")
dbutils.fs.ls("dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[117]: [FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv/_committed_3666297038110620406&#39;, name=&#39;_committed_3666297038110620406&#39;, size=113),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv/_started_3666297038110620406&#39;, name=&#39;_started_3666297038110620406&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv/part-00000-tid-3666297038110620406-c9686759-1526-4195-8e74-a538e4d93b38-473-1-c000.csv&#39;, name=&#39;part-00000-tid-3666297038110620406-c9686759-1526-4195-8e74-a538e4d93b38-473-1-c000.csv&#39;, size=77735731)]</div>

# %% [markdown]
# #### COPY TO DOWNLOAD FOLDER

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/BC-SV/bitcoin_sv_block_extended_df.csv", "dbfs:/FileStore/bitcoin_sv_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv",  "dbfs:/FileStore/bitcoin_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/Bitcoin-cash/bitcoin_cash_block_extended_df.csv",  "dbfs:/FileStore/bitcoin_cash_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/Dash/dash_block_extended_df.csv",  "dbfs:/FileStore/dash_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/Doge-Coin/dogecoin_block_extended_df.csv",  "dbfs:/FileStore/dogecoin_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/Ethereum/ehtereum_block_extended_df.csv",  "dbfs:/FileStore/ehtereum_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: True</div>

# %%
dbutils.fs.cp("dbfs:/mnt/BlockChain/Blocks/LiteCoin/litecoin_block_extended_df.csv",  "dbfs:/FileStore/litecoin_block_extended_df.csv", recurse = True )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: True</div>

# %%
dash_extended_preview_df = spark.read.csv("dbfs:/mnt/BlockChain/Blocks/BitCoin/bitcoin_block_extended_df.csv", inferSchema= True, header= True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dash_extended_preview_df.select("month").distinct().collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th></tr></thead><tbody><tr><td>12</td></tr><tr><td>1</td></tr><tr><td>6</td></tr><tr><td>3</td></tr><tr><td>5</td></tr><tr><td>9</td></tr><tr><td>4</td></tr><tr><td>8</td></tr><tr><td>7</td></tr><tr><td>10</td></tr><tr><td>11</td></tr><tr><td>2</td></tr></tbody></table></div>

# %%
dash_extended_preview_df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [&#39;ID&#39;,
#  &#39;time&#39;,
#  &#39;median_time&#39;,
#  &#39;size&#39;,
#  &#39;guessed_miner&#39;,
#  &#39;difficulty&#39;,
#  &#39;fee_total&#39;,
#  &#39;fee_total_usd&#39;,
#  &#39;reward&#39;,
#  &#39;reward_usd&#39;,
#  &#39;Date&#39;,
#  &#39;Year&#39;,
#  &#39;Month&#39;,
#  &#39;Week_of_Year&#39;,
#  &#39;isPool&#39;]</div>

# %%
display(dash_extended_preview_df.select("Date", "Week_of_Year").distinct().collect())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Date</th><th>Week_of_Year</th></tr></thead><tbody><tr><td>2014-03-23</td><td>12</td></tr><tr><td>2013-09-20</td><td>38</td></tr><tr><td>2010-07-13</td><td>28</td></tr><tr><td>2014-06-15</td><td>24</td></tr><tr><td>2011-06-19</td><td>24</td></tr><tr><td>2014-03-21</td><td>12</td></tr><tr><td>2016-12-13</td><td>50</td></tr><tr><td>2013-10-24</td><td>43</td></tr><tr><td>2018-01-23</td><td>4</td></tr><tr><td>2019-11-14</td><td>46</td></tr><tr><td>2019-10-22</td><td>43</td></tr><tr><td>2013-10-27</td><td>43</td></tr><tr><td>2011-05-16</td><td>20</td></tr><tr><td>2014-10-31</td><td>44</td></tr><tr><td>2014-09-17</td><td>38</td></tr><tr><td>2017-10-24</td><td>43</td></tr><tr><td>2014-05-10</td><td>19</td></tr><tr><td>2017-12-29</td><td>52</td></tr><tr><td>2010-10-20</td><td>42</td></tr><tr><td>2013-03-17</td><td>11</td></tr><tr><td>2011-06-20</td><td>25</td></tr><tr><td>2020-01-03</td><td>1</td></tr><tr><td>2018-07-19</td><td>29</td></tr><tr><td>2013-12-17</td><td>51</td></tr><tr><td>2020-11-20</td><td>47</td></tr><tr><td>2015-12-27</td><td>52</td></tr><tr><td>2013-09-01</td><td>35</td></tr><tr><td>2017-01-20</td><td>3</td></tr><tr><td>2017-12-11</td><td>50</td></tr><tr><td>2014-02-06</td><td>6</td></tr><tr><td>2018-08-27</td><td>35</td></tr><t